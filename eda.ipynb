# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_columns', 20)

# %%
h_sum_data=h.groupby(['label','day']).mean().col_sum.reset_index()
sns.relplot(x='day',y='col_sum',hue='label',kind='line',palette=sns.color_palette("hls", 3),data=h_sum_data)

# %%
b['col_sum']=b.iloc[:,1:641].sum(axis=1)
b_group=b.groupby(['label','day','month']).mean().reset_index()
sns.relplot(x='day',y='col_sum',hue='label',col='month',kind='line',palette=sns.color_palette("hls", 3),data=b_group)

# %%
h['col_max']=h.iloc[:,1:397].max(axis=1)
h_group=h.groupby(['label','day']).mean().reset_index()
sns.relplot(x='day',y='col_max',hue='label',kind='line',palette=sns.color_palette("hls", 3),data=h_group)

# %%
sns.relplot(x='day',y='col_max',hue='label',kind='line',palette=sns.color_palette("hls", 3),data=h_group)

# %%
b['col_max']=b.iloc[:,1:641].max(axis=1)
b_group=b.groupby(['label','day','month']).mean().reset_index()
sns.relplot(x='day',y='col_max',hue='label',col='month',kind='line',palette=sns.color_palette("hls", 3),data=b_group)

# %%
plt.figure(figsize=(20,20))
b11=b[b.day==11]
for label in [1]:
    data=b11[b11.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b11=b[b.day==11]
for label in [2]:
    data=b11[b11.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b11=b[b.day==11]
for label in [3]:
    data=b11[b11.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b10=b[b.day==10]
for label in [1]:
    data=b10[b10.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b10=b[b.day==10]
for label in [2]:
    data=b10[b10.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b10=b[b.day==10]
for label in [3]:
    data=b10[b10.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b9=b[b.day==9]
for label in [1]:
    data=b9[b9.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b9=b[b.day==9]
for label in [2]:
    data=b9[b9.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
b9=b[b.day==9]
for label in [3]:
    data=b9[b9.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(640),data.iloc[i,1:641]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data=h[h.day==0]
for label in [1]:
    data=data[data.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data=h[h.day==0]
for label in [2]:
    data=data[data.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data=h[h.day==0]
for label in [3]:
    data=data[data.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data_all=h[h.day==0]
for label in [1,2,3]:
    data=data_all[data_all.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data_all=h[h.day==1]
for label in [1,2,3]:
    data=data_all[data_all.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,20))
data_all=h[h.day==2]
for label in [1,2,3]:
    data=data_all[data_all.label==label].sample(5)
    for i in range(5):
        plt.subplot(5,1,i+1)
        sns.scatterplot(np.arange(396),data.iloc[i,1:397]).set(ylim=(0,18))

# %%
plt.figure(figsize=(20,30))
h_mean=h.groupby('day').mean()
for i in range(11):
    plt.subplot(11,1,i+1)
    sns.scatterplot(np.arange(396),h_mean.iloc[i,1:397]).set(ylim=(0,12))

# %%
plt.figure(figsize=(20,30))
b_mean=b.groupby(['day','month']).mean()
for i in range(14):
    plt.subplot(14,1,i+1)
    sns.scatterplot(np.arange(640),b_mean.iloc[i,1:641]).set(ylim=(0,18))
